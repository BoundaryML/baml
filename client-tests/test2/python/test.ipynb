# %%
import pandas as pd

# create a dataframe with columns - input.context, input.query, tool.CodeInterpreter, tool.DrawImage, tool.GenerateText
df = pd.DataFrame(columns=['input.context', 'input.query', 'tool.CodeInterpreter', 'tool.DrawImage', 'tool.GenerateText'])
# add 0 or 1s for the tool columns
df['tool.CodeInterpreter'] =  [0, 0, 0, 1, 0, 0]
df['tool.DrawImage'] =        [0, 1, 0, 0, 0, 0]
df['tool.GenerateText'] =     [1, 0, 1, 0, 1, 1]
df['tool.WebSearch'] = [None, None, None, None, 1, 0]
# add the context and query

# Fake context descriptions (personas)

contexts = [

    "Software engineer looking for code optimization techniques",

    "Artist seeking inspiration for a new art project",

    "Writer needing assistance with character development",

    "Data scientist searching for the latest trends in data visualization",

    "Teacher exploring interactive teaching tools",

    "Gamer asking for recommendations on strategy games"

]



# Fake queries (questions)

queries = [

    "What are the best practices for refactoring code?",

    "Can you suggest some modern art styles for my next piece?",

    "How do I create a compelling villain?",

    "What are the new tools available for data visualization?",

    "Which interactive platforms are best for online teaching?",

    "What are some well known adventure games?"

]



# Adding the fake context and query data to the dataframe

df['input.context'] = contexts

df['input.query'] = queries

# CONVERT ALL columsn to float except first 2
df = df.astype({'tool.CodeInterpreter': 'float', 'tool.DrawImage': 'float', 'tool.GenerateText': 'float', 'tool.WebSearch': 'float'})


# Display the updated dataframe

df.head()
# Out:
#                                        input.context  \
# 0  Software engineer looking for code optimizatio...
# 1   Artist seeking inspiration for a new art project
# 2  Writer needing assistance with character devel...
# 3  Data scientist searching for the latest trends...
# 4       Teacher exploring interactive teaching tools
#
#                                          input.query  tool.CodeInterpreter  \
# 0  What are the best practices for refactoring code?                   0.0
# 1  Can you suggest some modern art styles for my ...                   0.0
# 2              How do I create a compelling villain?                   0.0
# 3  What are the new tools available for data visu...                   1.0
# 4  Which interactive platforms are best for onlin...                   0.0
#
#    tool.DrawImage  tool.GenerateText  tool.WebSearch
# 0             0.0                1.0             NaN
# 1             1.0                0.0             NaN
# ...
